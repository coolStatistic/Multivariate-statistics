# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Principal-Component-Analysis" data-toc-modified-id="Principal-Component-Analysis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Principal Component Analysis</a></span><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Basics" data-toc-modified-id="Basics-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Basics</a></span></li><li><span><a href="#Computation" data-toc-modified-id="Computation-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Computation</a></span><ul class="toc-item"><li><span><a href="#R-packages" data-toc-modified-id="R-packages-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>R packages</a></span></li><li><span><a href="#Data-format" data-toc-modified-id="Data-format-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Data format</a></span></li><li><span><a href="#Data-standardization" data-toc-modified-id="Data-standardization-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Data standardization</a></span></li><li><span><a href="#R-code" data-toc-modified-id="R-code-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>R code</a></span></li></ul></li><li><span><a href="#Visualization--and-Interpretation" data-toc-modified-id="Visualization--and-Interpretation-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Visualization  and Interpretation</a></span><ul class="toc-item"><li><span><a href="#Eigenvalues-/-Variances" data-toc-modified-id="Eigenvalues-/-Variances-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Eigenvalues / Variances</a></span></li><li><span><a href="#Graph-of-variables" data-toc-modified-id="Graph-of-variables-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Graph of variables</a></span><ul class="toc-item"><li><span><a href="#Results" data-toc-modified-id="Results-1.4.2.1"><span class="toc-item-num">1.4.2.1&nbsp;&nbsp;</span>Results</a></span></li><li><span><a href="#Correlation-circle" data-toc-modified-id="Correlation-circle-1.4.2.2"><span class="toc-item-num">1.4.2.2&nbsp;&nbsp;</span>Correlation circle</a></span></li><li><span><a href="#Quality-of-representation" data-toc-modified-id="Quality-of-representation-1.4.2.3"><span class="toc-item-num">1.4.2.3&nbsp;&nbsp;</span>Quality of representation</a></span></li><li><span><a href="#Contributions-of-variables" data-toc-modified-id="Contributions-of-variables-1.4.2.4"><span class="toc-item-num">1.4.2.4&nbsp;&nbsp;</span>Contributions of variables</a></span></li><li><span><a href="#Color-by-a-custom-continuous-variable" data-toc-modified-id="Color-by-a-custom-continuous-variable-1.4.2.5"><span class="toc-item-num">1.4.2.5&nbsp;&nbsp;</span>Color by a custom continuous variable</a></span></li><li><span><a href="#Color-by-groups" data-toc-modified-id="Color-by-groups-1.4.2.6"><span class="toc-item-num">1.4.2.6&nbsp;&nbsp;</span>Color by groups</a></span></li></ul></li><li><span><a href="#Dimension-description" data-toc-modified-id="Dimension-description-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Dimension description</a></span></li><li><span><a href="#Graph-of-individuals" data-toc-modified-id="Graph-of-individuals-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Graph of individuals</a></span><ul class="toc-item"><li><span><a href="#Result" data-toc-modified-id="Result-1.4.4.1"><span class="toc-item-num">1.4.4.1&nbsp;&nbsp;</span>Result</a></span></li><li><span><a href="#Plots:-quality-and-contribution" data-toc-modified-id="Plots:-quality-and-contribution-1.4.4.2"><span class="toc-item-num">1.4.4.2&nbsp;&nbsp;</span>Plots: quality and contribution</a></span></li><li><span><a href="#Color-by-a-custom-continuous-variables" data-toc-modified-id="Color-by-a-custom-continuous-variables-1.4.4.3"><span class="toc-item-num">1.4.4.3&nbsp;&nbsp;</span>Color by a custom continuous variables</a></span></li><li><span><a href="#Color-by-groups" data-toc-modified-id="Color-by-groups-1.4.4.4"><span class="toc-item-num">1.4.4.4&nbsp;&nbsp;</span>Color by groups</a></span></li></ul></li><li><span><a href="#Graph-customization" data-toc-modified-id="Graph-customization-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>Graph customization</a></span><ul class="toc-item"><li><span><a href="#Dimensions" data-toc-modified-id="Dimensions-1.4.5.1"><span class="toc-item-num">1.4.5.1&nbsp;&nbsp;</span>Dimensions</a></span></li><li><span><a href="#Plot-elements:-point,-text,-arrow" data-toc-modified-id="Plot-elements:-point,-text,-arrow-1.4.5.2"><span class="toc-item-num">1.4.5.2&nbsp;&nbsp;</span>Plot elements: point, text, arrow</a></span></li><li><span><a href="#Size-and-shape-of-plot-elements" data-toc-modified-id="Size-and-shape-of-plot-elements-1.4.5.3"><span class="toc-item-num">1.4.5.3&nbsp;&nbsp;</span>Size and shape of plot elements</a></span></li><li><span><a href="#Ellipses" data-toc-modified-id="Ellipses-1.4.5.4"><span class="toc-item-num">1.4.5.4&nbsp;&nbsp;</span>Ellipses</a></span></li><li><span><a href="#Group-mean-points" data-toc-modified-id="Group-mean-points-1.4.5.5"><span class="toc-item-num">1.4.5.5&nbsp;&nbsp;</span>Group mean points</a></span></li><li><span><a href="#Axis-lines" data-toc-modified-id="Axis-lines-1.4.5.6"><span class="toc-item-num">1.4.5.6&nbsp;&nbsp;</span>Axis lines</a></span></li><li><span><a href="#Graphical-paremeters" data-toc-modified-id="Graphical-paremeters-1.4.5.7"><span class="toc-item-num">1.4.5.7&nbsp;&nbsp;</span>Graphical paremeters</a></span></li></ul></li><li><span><a href="#Biplot" data-toc-modified-id="Biplot-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>Biplot</a></span></li></ul></li><li><span><a href="#Supplementary-elements" data-toc-modified-id="Supplementary-elements-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Supplementary elements</a></span><ul class="toc-item"><li><span><a href="#Definition-and-types" data-toc-modified-id="Definition-and-types-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Definition and types</a></span></li><li><span><a href="#Specification-in-PCA" data-toc-modified-id="Specification-in-PCA-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Specification in PCA</a></span></li><li><span><a href="#Quantitative-variables" data-toc-modified-id="Quantitative-variables-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Quantitative variables</a></span></li><li><span><a href="#Individuals" data-toc-modified-id="Individuals-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Individuals</a></span></li><li><span><a href="#Quantitative-variables" data-toc-modified-id="Quantitative-variables-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>Quantitative variables</a></span></li></ul></li><li><span><a href="#Filtering-results" data-toc-modified-id="Filtering-results-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Filtering results</a></span></li><li><span><a href="#Exporting-result" data-toc-modified-id="Exporting-result-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Exporting result</a></span><ul class="toc-item"><li><span><a href="#Export-plots-to-PDF/PNG-files" data-toc-modified-id="Export-plots-to-PDF/PNG-files-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>Export plots to PDF/PNG files</a></span></li><li><span><a href="#Export-results-txt/csv-files" data-toc-modified-id="Export-results-txt/csv-files-1.7.2"><span class="toc-item-num">1.7.2&nbsp;&nbsp;</span>Export results txt/csv files</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Principal Component Analysis
# reference: *Practical Guide to Principal	Component Methods in R*, by Alboukadel

# %% [markdown]
# ### Introduction
# >Principal component analysis (PCA) allows us to summarize and to visualize the
# information in a data set containing individuals/observations described by multiple inter-
# correlated quantitative variables
#
# >In other words, PCA reduces the dimensionality of a multivariate data to two or three
# principal components, that can be visualized graphically, with minimal loss of informa-
# tion.

# %% [markdown]
# ### Basics
# >Technically speaking, the amount of variance retained by each principal component is
# measured by the so-called eigenvalue.
#
# >Note that, the PCA method is particularly useful when the variables within the data set
# are highly correlated. Correlation indicates that there is redundancy in the data. Due to
# this redundancy, PCA can be used to reduce the original variables into a smaller number
# of new variables ( = principal components) explaining most of the variance in the
# original variables.
#
# >Taken together, the main purpose of principal component analysis is to:
# >identify hidden pattern in a data set;
# >reduce the dimensionnality of the data by removing the noise and redundancy in the data;
# >identify correlated variables

# %% [markdown]
# ### Computation

# %% [markdown]
# #### R packages

# %%
library("FactoMineR")
library("factoextra")
# Out:
# Loading required package: ggplot2
# Welcome! Related Books: `Practical Guide To Cluster Analysis in R` at https://goo.gl/13EFCZ

# %% [markdown]
# #### Data format

# %%
data(decathlon2)
head(decathlon2)
# Out:
#           X100m Long.jump Shot.put High.jump X400m X110m.hurdle Discus
# SEBRLE    11.04 7.58      14.83    2.07      49.81 14.69        43.75
# CLAY      10.76 7.40      14.26    1.86      49.37 14.05        50.72
# BERNARD   11.02 7.23      14.25    1.92      48.93 14.99        40.87
# YURKOV    11.34 7.09      15.19    2.10      50.42 15.31        46.26
# ZSIVOCZKY 11.13 7.30      13.48    2.01      48.62 14.17        45.67
# McMULLEN  10.83 7.31      13.76    2.13      49.91 14.38        44.41
#           Pole.vault Javeline X1500m Rank Points Competition
# SEBRLE    5.02       63.19    291.7  1    8217   Decastar
# CLAY      4.92       60.15    301.5  2    8122   Decastar
# BERNARD   5.32       62.77    280.1  4    8067   Decastar
# YURKOV    4.72       63.44    276.4  5    8036   Decastar
# ZSIVOCZKY 4.42       55.37    268.0  7    8004   Decastar
# McMULLEN  4.42       56.37    285.1  8    7995   Decastar

# %% [markdown]
# >Note that, only some of these individuals and variables will be used to perform the
# principal component analysis. The coordinates of the remaining individuals and
# variables on the factor map will be predicted after the PCA.

# %%
decathlon2.active <- decathlon2[1:23, 1:10]
head(decathlon2.active[, 1:6], 4)
# Out:
#         X100m Long.jump Shot.put High.jump X400m X110m.hurdle
# SEBRLE  11.04 7.58      14.83    2.07      49.81 14.69
# CLAY    10.76 7.40      14.26    1.86      49.37 14.05
# BERNARD 11.02 7.23      14.25    1.92      48.93 14.99
# YURKOV  11.34 7.09      15.19    2.10      50.42 15.31

# %% [markdown]
# #### Data standardization
# >In principal component analysis, variables are often scaled (i.e. standardized). This is
# particularly recommended when variables are measured in different scales (e.g: kilograms,
# kilometers, centimeters, ...); otherwise, the PCA outputs obtained will be severely affected.
#
# >Note that, by default, the function PCA() [in FactoMineR], standardizes the data
# automatically during the PCA; so you don’t need do this transformation before the
# PCA.

# %% [markdown]
# #### R code

# %%
res.pca <- PCA(decathlon2.active, graph = FALSE)
res.pca
# Out:
# **Results for the Principal Component Analysis (PCA)**
# The analysis was performed on 23 individuals, described by 10 variables
# *The results are available in the following objects:
#
#    name               description
# 1  "$eig"             "eigenvalues"
# 2  "$var"             "results for the variables"
# 3  "$var$coord"       "coord. for the variables"
# 4  "$var$cor"         "correlations variables - dimensions"
# 5  "$var$cos2"        "cos2 for the variables"
# 6  "$var$contrib"     "contributions of the variables"
# 7  "$ind"             "results for the individuals"
# 8  "$ind$coord"       "coord. for the individuals"
# 9  "$ind$cos2"        "cos2 for the individuals"
# 10 "$ind$contrib"     "contributions of the individuals"
# 11 "$call"            "summary statistics"
# 12 "$call$centre"     "mean of the variables"
# 13 "$call$ecart.type" "standard error of the variables"
# 14 "$call$row.w"      "weights for the individuals"
# ...

# %% [markdown]
# ### Visualization  and Interpretation

# %% [markdown]
# #### Eigenvalues / Variances

# %%
eig.val <- get_eigenvalue(res.pca)
eig.val
# Out:
#        eigenvalue variance.percent cumulative.variance.percent
# Dim.1  4.1242133  41.242133         41.24213
# Dim.2  1.8385309  18.385309         59.62744
# Dim.3  1.2391403  12.391403         72.01885
# Dim.4  0.8194402   8.194402         80.21325
# Dim.5  0.7015528   7.015528         87.22878
# Dim.6  0.4228828   4.228828         91.45760
# Dim.7  0.3025817   3.025817         94.48342
# Dim.8  0.2744700   2.744700         97.22812
# Dim.9  0.1552169   1.552169         98.78029
# Dim.10 0.1219710   1.219710        100.00000

# %% [markdown]
# >The sum of all the eigenvalues give a total variance of 10.
#
# (Kaiser, 1961)
# >An eigenvalue > 1 indicates that PCs account for more variance than accounted
# by one of the original variables in standardized data. This is commonly used
# as a cutoff point for which PCs are retained. This holds true only when the
# data are standardized.
#
#
# >You can also limit the number of component to that number that accounts
# for a certain fraction of the total variance. For example, if you are satisfied
# with 70% of the total variance explained then use the number of components
# to achieve that.

# %%
options(repr.plot.width=9, repr.plot.height=4)
fviz_eig(res.pca, addlabels = TRUE, ylim = c(0, 50))
# Out:
# plot without title

# %% [markdown]
# >From the plot above, we might want to stop at the fifth principal component. 87%
# of the information (variances) contained in the data are retained by the first five
# principal components.

# %% [markdown]
# #### Graph of variables

# %% [markdown]
# ##### Results

# %%
var <- get_pca_var(res.pca)
var
# Out:
# Principal Component Analysis Results for variables
# ...
#   Name       Description
# 1 "$coord"   "Coordinates for the variables"
# 2 "$cor"     "Correlations between variables and dimensions"
# 3 "$cos2"    "Cos2 for the variables"
# 4 "$contrib" "contributions of the variables"

# %%
# Coodrinates(因子载荷阵)
head(var$coord)
# Out:
#              Dim.1      Dim.2       Dim.3      Dim.4       Dim.5
# X100m        -0.8506257 -0.17939806  0.3015564  0.03357320 -0.1944440
# Long.jump     0.7941806  0.28085695 -0.1905465 -0.11538956  0.2331567
# Shot.put      0.7339127  0.08540412  0.5175978  0.12846837 -0.2488129
# High.jump     0.6100840 -0.46521415  0.3300852  0.14455012  0.4027002
# X400m        -0.7016034  0.29017826  0.2835329  0.43082552  0.1039085
# X110m.hurdle -0.7641252 -0.02474081  0.4488873 -0.01689589  0.2242200

# %%
# Cos2: quality on the factore map
# 因子载荷阵的平方(element-wise)
var.my.cos2 <- var$coord^2
head(var.my.cos2)
# Out:
#              Dim.1     Dim.2        Dim.3      Dim.4        Dim.5
# X100m        0.7235641 0.0321836641 0.09093628 0.0011271597 0.03780845
# Long.jump    0.6307229 0.0788806285 0.03630798 0.0133147506 0.05436203
# Shot.put     0.5386279 0.0072938636 0.26790749 0.0165041211 0.06190783
# High.jump    0.3722025 0.2164242070 0.10895622 0.0208947375 0.16216747
# X400m        0.4922473 0.0842034209 0.08039091 0.1856106269 0.01079698
# X110m.hurdle 0.5838873 0.0006121077 0.20149984 0.0002854712 0.05027463

# %%
head(var$cos2)
# Out:
#              Dim.1     Dim.2        Dim.3      Dim.4        Dim.5
# X100m        0.7235641 0.0321836641 0.09093628 0.0011271597 0.03780845
# Long.jump    0.6307229 0.0788806285 0.03630798 0.0133147506 0.05436203
# Shot.put     0.5386279 0.0072938636 0.26790749 0.0165041211 0.06190783
# High.jump    0.3722025 0.2164242070 0.10895622 0.0208947375 0.16216747
# X400m        0.4922473 0.0842034209 0.08039091 0.1856106269 0.01079698
# X110m.hurdle 0.5838873 0.0006121077 0.20149984 0.0002854712 0.05027463

# %%
# Test if Two Objects are (Nearly) Equal
all.equal(var.my.cos2, var$cos2)
# Out:
# [1] TRUE

# %%
# Contributions to the principal components
# 贡献度由百分比表示：cos2中每个元素比上所在列的和
var$cos2[1,1]/sum(var$cos2[,1])
# Out:
# [1] 0.1754429

# %%
# 由cos2计算contrib
var.my.contrib <- apply(var$cos2, 2, function(x){100*x/sum(x)})
head(var.my.contrib)
# Out:
#              Dim.1     Dim.2      Dim.3     Dim.4       Dim.5
# X100m        17.544293  1.7505098  7.338659  0.13755240  5.389252
# Long.jump    15.293168  4.2904162  2.930094  1.62485936  7.748815
# Shot.put     13.060137  0.3967224 21.620432  2.01407269  8.824401
# High.jump     9.024811 11.7715838  8.792888  2.54987951 23.115504
# X400m        11.935544  4.5799296  6.487636 22.65090599  1.539012
# X110m.hurdle 14.157544  0.0332933 16.261261  0.03483735  7.166193

# %%
# Contributions to the principal components
head(var$contrib)
# Out:
#              Dim.1     Dim.2      Dim.3     Dim.4       Dim.5
# X100m        17.544293  1.7505098  7.338659  0.13755240  5.389252
# Long.jump    15.293168  4.2904162  2.930094  1.62485936  7.748815
# Shot.put     13.060137  0.3967224 21.620432  2.01407269  8.824401
# High.jump     9.024811 11.7715838  8.792888  2.54987951 23.115504
# X400m        11.935544  4.5799296  6.487636 22.65090599  1.539012
# X110m.hurdle 14.157544  0.0332933 16.261261  0.03483735  7.166193

# %%
# Test if Two Objects are (Nearly) Equal
all.equal(var.my.contrib, var$contrib)
# Out:
# [1] TRUE

# %% [markdown]
# ##### Correlation circle

# %%
# Coordinates of variables
head(var$coord, 4)
# Out:
#           Dim.1      Dim.2       Dim.3      Dim.4      Dim.5
# X100m     -0.8506257 -0.17939806  0.3015564  0.0335732 -0.1944440
# Long.jump  0.7941806  0.28085695 -0.1905465 -0.1153896  0.2331567
# Shot.put   0.7339127  0.08540412  0.5175978  0.1284684 -0.2488129
# High.jump  0.6100840 -0.46521415  0.3300852  0.1445501  0.4027002

# %%
fviz_pca_var(res.pca, col.var = "black")
# Out:
# plot without title

# %% [markdown]
# ##### Quality of representation

# %%
head(var$cos2, 4)
# Out:
#           Dim.1     Dim.2       Dim.3      Dim.4      Dim.5
# X100m     0.7235641 0.032183664 0.09093628 0.00112716 0.03780845
# Long.jump 0.6307229 0.078880629 0.03630798 0.01331475 0.05436203
# Shot.put  0.5386279 0.007293864 0.26790749 0.01650412 0.06190783
# High.jump 0.3722025 0.216424207 0.10895622 0.02089474 0.16216747

# %%
# Total cos2 of variables on Dim.1 and Dim.2
fviz_cos2(res.pca, choice = "var", axes = 1:2)
# Out:
# plot without title

# %% [markdown]
# Note that,
# >A high cos2 indicates a good representation of the variable on the principal
# component. In this case the variable is positioned close to the circumference
# of the correlation circle.
#
# >A low cos2 indicates that the variable is not perfectly represented by the PCs.
# In this case the variable is close to the center of the circle.
#
# >For a given variable, the sum of the cos2 on all the principal components is equal to one.

# %%
# Color by cos2 values: quality on the factor map
fviz_pca_var(res.pca, col.var = "cos2",
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"),
             repel = TRUE # Avoid text overlapping
            )
# Out:
# plot without title

# %%
# Change the transparency by cos2 values
fviz_pca_var(res.pca, alpha.var = "cos2")
# Out:
# plot without title

# %% [markdown]
# ##### Contributions of variables

# %%
head(var$contrib, 4)
# Out:
#           Dim.1     Dim.2      Dim.3     Dim.4     Dim.5
# X100m     17.544293  1.7505098  7.338659 0.1375524  5.389252
# Long.jump 15.293168  4.2904162  2.930094 1.6248594  7.748815
# Shot.put  13.060137  0.3967224 21.620432 2.0140727  8.824401
# High.jump  9.024811 11.7715838  8.792888 2.5498795 23.115504

# %% [markdown]
# 行向观察：
# >The larger the value of the contribution, the more the variable contributes to the
# component.

# %%
# highlight the most contributing variables for each dimension
corrplot(var$contrib, is.corr = FALSE)
# Out:
# Error in corrplot(var$contrib, is.corr = FALSE): could not find function "corrplot"
# Traceback:

# %%
fviz_contrib(res.pca, choice = "var", axes = 1, top = 10)
# Out:
# plot without title

# %%
fviz_contrib(res.pca, choice = "var", axes = 2, top = 10)
# Out:
# plot without title

# %%
fviz_contrib(res.pca, choice = "var", axes = 1:2, top = 10)
# Out:
# plot without title

# %% [markdown]
# >The red dashed line on the graph above indicates the expected average contribu-
# tion. If the contribution of the variables were uniform, the expected value would
# be 1/length(variables) = 1/10 = 10%. For a given component, a variable with a
# contribution larger than this cutoff could be considered as important in contributing to
# the component.

# %%
fviz_pca_var(res.pca, col.var = "contrib",
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07")
            )
# Out:
# plot without title

# %%
# Change the transparency by contrib values
fviz_pca_var(res.pca, alpha.var = "contrib")
# Out:
# plot without title

# %% [markdown]
# ##### Color by a custom continuous variable

# %%
# Create a random continuous variable of length 10
set.seed(123)
my.cont.var <- rnorm(10)
# Color variables by the continuous variable
fviz_pca_var(res.pca, col.var = my.cont.var,
             gradient.cols = c("blue", "yellow", "red"),
             legend.title = "Cont.Var")
# Out:
# plot without title

# %% [markdown]
# ##### Color by groups

# %%
# Create a grouping variable using kmeans
# Create 3 groups of variables (centers = 3)
set.seed(123)
res.km <- kmeans(var$coord, centers = 3, nstart = 15)
grp <- as.factor(res.km$cluster)
grp
# Out:
#        X100m    Long.jump     Shot.put    High.jump        X400m X110m.hurdle
#            3            1            1            1            3            3
#       Discus   Pole.vault     Javeline       X1500m
#            1            2            1            2
# Levels: 1 2 3

# %%
# Color variables by groups
fviz_pca_var(res.pca, col.var = grp,
            paletter = c("#0073C2FF", "#EFC000FF", "#868686FF"),
            legend.title = "Cluster")
# Out:
# plot without title

# %% [markdown]
# #### Dimension description

# %%
res.desc <- dimdesc(res.pca, axes = c(1, 2),
                   proba = 0.05)
res.desc$Dim.1
# Out:
# $quanti
#              correlation      p.value
# Long.jump      0.7941806 6.059893e-06
# Discus         0.7432090 4.842563e-05
# Shot.put       0.7339127 6.723102e-05
# High.jump      0.6100840 1.993677e-03
# Javeline       0.4282266 4.149192e-02
# X400m         -0.7016034 1.910387e-04
# X110m.hurdle  -0.7641252 2.195812e-05
# X100m         -0.8506257 2.727129e-07

# %%
# Description of dimension 2
res.desc$Dim.2
# Out:
# $quanti
#            correlation      p.value
# Pole.vault   0.8074511 3.205016e-06
# X1500m       0.7844802 9.384747e-06
# High.jump   -0.4652142 2.529390e-02

# %% [markdown]
# #### Graph of individuals

# %% [markdown]
# ##### Result

# %%
ind <- get_pca_ind(res.pca)
ind
# Out:
# Principal Component Analysis Results for individuals
# ...
#   Name       Description
# 1 "$coord"   "Coordinates for the individuals"
# 2 "$cos2"    "Cos2 for the individuals"
# 3 "$contrib" "contributions of the individuals"

# %%
# Coordinates of individuals
head(ind$coord)
# Out:
#           Dim.1      Dim.2      Dim.3      Dim.4       Dim.5
# SEBRLE     0.1955047  1.5890567  0.6424912  0.08389652  1.16829387
# CLAY       0.8078795  2.4748137 -1.3873827  1.29838232 -0.82498206
# BERNARD   -1.3591340  1.6480950  0.2005584 -1.96409420  0.08419345
# YURKOV    -0.8889532 -0.4426067  2.5295843  0.71290837  0.40782264
# ZSIVOCZKY -0.1081216 -2.0688377 -1.3342591 -0.10152796 -0.20145217
# McMULLEN   0.1212195 -1.0139102 -0.8625170  1.34164291  1.62151286

# %%
# Quality of individuals
head(ind$cos2)
# Out:
#           Dim.1       Dim.2      Dim.3       Dim.4       Dim.5
# SEBRLE    0.007530179 0.49747323 0.081325232 0.001386688 0.2689026575
# CLAY      0.048701249 0.45701660 0.143628117 0.125791741 0.0507850580
# BERNARD   0.197199804 0.28996555 0.004294015 0.411819183 0.0007567259
# YURKOV    0.096109800 0.02382571 0.778230322 0.061812637 0.0202279796
# ZSIVOCZKY 0.001574385 0.57641944 0.239754152 0.001388216 0.0054654972
# McMULLEN  0.002175437 0.15219499 0.110137872 0.266486530 0.3892621478

# %%
# Contributions of individuals
head(ind$contrib)
# Out:
#           Dim.1      Dim.2      Dim.3      Dim.4       Dim.5
# SEBRLE    0.04029447  5.9714533  1.4483919  0.03734589  8.45894063
# CLAY      0.68805664 14.4839248  6.7537381  8.94458283  4.21794385
# BERNARD   1.94740183  6.4234107  0.1411345 20.46819433  0.04393073
# YURKOV    0.83308415  0.4632733 22.4517396  2.69663605  1.03075263
# ZSIVOCZKY 0.01232413 10.1217143  6.2464325  0.05469230  0.25151025
# McMULLEN  0.01549089  2.4310854  2.6102794  9.55055888 16.29493304

# %% [markdown]
# ##### Plots: quality and contribution

# %%
fviz_pca_ind(res.pca)
# Out:
# plot without title

# %%
fviz_pca_ind(res.pca, col.ind = "cos2",
            gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"),
             repel = TRUE)
# Out:
# plot without title

# %% [markdown]
# >Note that, individuals that are similar are grouped together on the plot.

# %%
fviz_pca_ind(res.pca, pointsize = "cos2",
            pointshape = 21, fill = "#E7B800",
            repel = TRUE)
# Out:
# plot without title

# %%
# To change both point size and color by cos2
fviz_pca_ind(res.pca, col.ind = "cos2", pointsize = "cos2",
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"),
             repel = TRUE # Avoid text overlapping (slow if many points)
            )
# Out:
# plot without title

# %%
fviz_cos2(res.pca, choice = "ind")
# Out:
# plot without title

# %%
# Total contribution on PC1 and PC2
fviz_contrib(res.pca, choice = "ind", axes = 1:2)
# Out:
# plot without title

# %% [markdown]
# ##### Color by a custom continuous variables

# %%
# Create a random continuous variables of length 23
set.seed(123)
my.cont.var <- rnorm(23)

# Color variables by the continuous variable
fviz_pca_ind(res.pca, col.ind = my.cont.var,
            gradient.cols = c("blue", "yellow", "red"),
            legend.title = "Cont.Var")
# Out:
# plot without title

# %% [markdown]
# ##### Color by groups

# %%
head(iris, 3)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa

# %%
# The variable Species (index=5) is removed
# before PCA analysis
iris.pca <- PCA(iris[, -5], graph = FALSE)

# %%
fviz_pca_ind(iris.pca, 
            geom.ind = "point",
            col.ind = iris$Species,
            palette = c("#00AFBB", "#E7B800", "#FC4E07"),
            addEllipses = TRUE,
            legend.title = "Groups"
            )
# Out:
# plot without title

# %%
# Add confidence ellipses
fviz_pca_ind(iris.pca, geom.ind = "point", col.ind = iris$Species,
             palette = c("#00AFBB", "#E7B800", "#FC4E07"),
             addEllipses = TRUE, ellipse.type = "confidence",
             legend.title = "Groups"
            )
# Out:
# plot without title

# %%
# use the jco (journal of clinical oncology) color palette
fviz_pca_ind(iris.pca,
             label = "none", # hide individual labels
             habillage = iris$Species, # color by groups
             addEllipses = TRUE, # Concentration ellipses
             palette = "jco"
             )
# Out:
# plot without title

# %% [markdown]
# #### Graph customization

# %% [markdown]
# ##### Dimensions
# >By default, variables/individuals are represented on dimensions 1 and 2. If you want to
# visualize them on dimensions 2 and 3, for example, you should specify the argument axes
# = c(2, 3).

# %%
# Varables on dimension 2 and 3
fviz_pca_var(res.pca, axes = c(2, 3))
# Out:
# plot without title

# %%
# Individuals on dimensions 2 and 3
fviz_pca_ind(res.pca, axes = c(2,3))
# Out:
# plot without title

# %% [markdown]
# ##### Plot elements: point, text, arrow

# %% [markdown]
# >geom.var: a text specifying the geometry to be used for plotting variables. Allowed
# values are the combination of c(“point”, “arrow”, “text”).

# %%
# Show variable points and text labels
fviz_pca_var(res.pca, geom.var = c("points", "text"))
# Out:
# plot without title

# %% [markdown]
# >geom.ind: a text specifying the geometry to be used for plotting individuals. Al-
# lowed values are the combination of c(“point”, “text”)

# %%
# Show individuals text labels only
fviz_pca_ind(res.pca, geom.ind = "text")
# Out:
# plot without title

# %% [markdown]
# ##### Size and shape of plot elements

# %%
# Change the size of arrow an labels
fviz_pca_var(res.pca, arrowsize = 1, labelsize = 5,
            repel = TRUE)
# Out:
# plot without title

# %%
# Change points size, size shape and fill color
# Change labelsize
fviz_pca_ind(res.pca, 
            pointsize = 3, pointshape = 21, fill = "lightblue",
            labelsize = 5, repel = TRUE)
# Out:
# plot without title

# %% [markdown]
# ##### Ellipses

# %%
# Add confidence ellipses
fviz_pca_ind(iris.pca, geom.ind = "point",
            col.ind = iris$Species,
            palette = c("#00AFBB", "#E7B800", "#FC4E07"),
            addEllipses = TRUE, ellipse.type = "confidence",
            legend.title = "Groups"
            )
# Out:
# plot without title

# %%
# Convex hull
fviz_pca_ind(iris.pca, geom.ind = "point",
            col.ind = iris$Species,
            palette = c("#00AFBB", "#E7B800", "#FC4E07"),
            addEllipses = TRUE, ellipse.type = "convex",
            legend.title = "Groups"
            )
# Out:
# plot without title

# %% [markdown]
# ##### Group mean points

# %%
fviz_pca_ind(iris.pca, geom.ind = "point",
            col.ind = iris$Species,
            legend.title = "Groups",
             mean.point = FALSE
            )
# Out:
# plot without title

# %% [markdown]
# ##### Axis lines

# %%
# remove axis lines
fviz_pca_var(res.pca, axes.linetype = "blank")
# Out:
# plot without title

# %% [markdown]
# ##### Graphical paremeters
# >To change easily the graphical of any ggplots, you can use the function ggpar() 1 [ggpubr
# package]

# %%
ind.p <- fviz_pca_ind(iris.pca, geom = "point", col.ind = iris$Species)
ggpubr::ggpar(ind.p,
             title = "Principal Component Analysis",
             subtitle = "Iris data set",
             caption = "Source: factoextra",
             xlab = "PC1", ylab = "PC2",
             legend.title = "Species", legend.position = "top",
             ggtheme =theme_gray(),
             palette = "jco"
             )
# Out:
# plot without title

# %% [markdown]
# #### Biplot

# %%
fviz_pca_biplot(res.pca, repel = TRUE,
               col.var = "#2E9FDF",
               col.ind = "#696969")
# Out:
# plot without title

# %% [markdown]
# >Note that, the biplot might be only useful when there is a low number of variables
# and individuals in the data set; otherwise the final plot would be unreadable.
# Note also that, the coordinate of individuals and variables are note constructed on
# the same space. Therefore, on biplot, you should mainly focus on the direction of
# variables but not on their absolute positions on the plot.
#
# Roughly speaking a biplot can be interpreted as follow:
# >an individual that is on the same side of a given variable has a high value for
# this variable;
#
# >an individual that is on the opposite side of a given variable has a low value for this variable

# %%
fviz_pca_biplot(iris.pca, 
                col.ind = iris$Species, palette = "jco",
                addEllipses = TRUE, label = "var",
                col.var = "black", repel = TRUE,
                legend.title = "Species"
               )
# Out:
# plot without title

# %%
fviz_pca_biplot(iris.pca,
    # Fill individuals by groups
    geom.ind = "point",
    pointshape = 21,
    pointsize = 2.5,
    fill.ind = iris$Species,
    col.ind = "black",
    # Color variable by groups
    col.var = factor(c("sepal", "sepal", "petal", "petal")),
    legend.title = list(fill = "Species", color = "Clusters"),
    repel = TRUE
)+
ggpubr::fill_palette("jco")+   # Indiviual fill color
ggpubr::color_palette("npg")  # Variable colors
# Out:
# plot without title

# %%
fviz_pca_biplot(iris.pca,
    # Individuals
    geom.ind = "point",
    fill.ind = iris$Species, col.ind = "black",
    pointshape = 21, pointsize = 2,
    palette = "jco",
    addEllipses = TRUE,
    # Variables
    alpha.var ="contrib", col.var = "contrib",
    gradient.cols = "RdYlBu",
    legend.title = list(fill = "Species", color = "Contrib",
    alpha = "Contrib")
)
# Out:
# plot without title

# %% [markdown]
# ### Supplementary elements

# %% [markdown]
# #### Definition and types
# >Supplementary variables and individuals are not used for the determination of the principal components. Their coordinates are predicted using only the information provided by the performed principal component analysis on active variables/individuals.

# %% [markdown]
# #### Specification in PCA

# %%
res.pca <- PCA(decathlon2, ind.sup = 24:27,
              quanti.sup = 11:12, quali.sup = 13,
              graph = FALSE)

# %% [markdown]
# #### Quantitative variables

# %%
res.pca$quanti.sup
# Out:
# $coord
#             Dim.1       Dim.2      Dim.3       Dim.4       Dim.5
# Rank   -0.7014777 -0.24519443 -0.1834294  0.05575186 -0.07382647
# Points  0.9637075  0.07768262  0.1580225 -0.16623092 -0.03114711
#
# $cor
#             Dim.1       Dim.2      Dim.3       Dim.4       Dim.5
# Rank   -0.7014777 -0.24519443 -0.1834294  0.05575186 -0.07382647
# Points  0.9637075  0.07768262  0.1580225 -0.16623092 -0.03114711
#
# $cos2
#            Dim.1       Dim.2      Dim.3      Dim.4        Dim.5
# Rank   0.4920710 0.060120310 0.03364635 0.00310827 0.0054503477
# Points 0.9287322 0.006034589 0.02497110 0.02763272 0.0009701427

# %%
fviz_pca_var(res.pca)
# Out:
# plot without title

# %% [markdown]
# >Note that, by default, supplementary quantitative variables are shown in blue color
# and dashed lines.

# %%
# Change color of variables 
fviz_pca_var(res.pca, col.var = "black",
            col.quanti.sup = "red"
            )
# Out:
# plot without title

# %%
# Hide active variables on the plot
fviz_pca_var(res.pca, invisible = "var")
# Out:
# plot without title

# %%
# Hide supplementary variables
fviz_pca_var(res.pca, invisible = "quanti.sup")
# Out:
# plot without title

# %%
# Plot of active variables
p <- fviz_pca_var(res.pca, invisible = "quanti.sup")
# Add supplementary active variables
fviz_add(p, res.pca$quanti.sup$coord, 
        geom = c("arrow", "text"),
        color = "red")
# Out:
# plot without title

# %% [markdown]
# #### Individuals

# %%
res.pca$ind.sup
# Out:
# $coord
#              Dim.1       Dim.2      Dim.3      Dim.4       Dim.5
# KARPOV   0.7947206  0.77951227 -1.6330203  1.7242283 -0.75070396
# WARNERS -0.3864645 -0.12159237 -1.7387332 -0.7063341 -0.03230011
# Nool    -0.5591306  1.97748871 -0.4830358 -2.2784526 -0.25461493
# Drews   -1.1092038  0.01741477 -3.0488182 -1.5343468 -0.32642192
#
# $cos2
#              Dim.1        Dim.2      Dim.3      Dim.4        Dim.5
# KARPOV  0.05104677 4.911173e-02 0.21553730 0.24028620 0.0455487744
# WARNERS 0.02422707 2.398250e-03 0.49039677 0.08092862 0.0001692349
# Nool    0.02897149 3.623868e-01 0.02162236 0.48108780 0.0060077529
# Drews   0.09207094 2.269527e-05 0.69560547 0.17617609 0.0079736753
#
# $dist
#   KARPOV  WARNERS     Nool    Drews
# 3.517470 2.482899 3.284943 3.655527

# %%
p <- fviz_pca_ind(res.pca, col.ind.sup = "blue",
                 repel = TRUE)
p <- fviz_add(p, res.pca$quanti.sup$coord,
             color = "red")
p
# Out:
# plot without title

# %% [markdown]
# #### Quantitative variables

# %%
res.pca$quali
# Out:
# $coord
#              Dim.1      Dim.2       Dim.3      Dim.4      Dim.5
# Decastar -1.343451  0.1218097 -0.03789524  0.1808357  0.1343364
# OlympicG  1.231497 -0.1116589  0.03473730 -0.1657661 -0.1231417
#
# $cos2
#              Dim.1       Dim.2        Dim.3      Dim.4       Dim.5
# Decastar 0.9051233 0.007440939 0.0007201669 0.01639956 0.009050062
# OlympicG 0.9051233 0.007440939 0.0007201669 0.01639956 0.009050062
#
# $v.test
#              Dim.1      Dim.2      Dim.3      Dim.4      Dim.5
# Decastar -2.970766  0.4034256 -0.1528767  0.8971036  0.7202457
# OlympicG  2.970766 -0.4034256  0.1528767 -0.8971036 -0.7202457
#
# $dist
# Decastar OlympicG
# 1.412108 1.294433
#
# $eta2
#                 Dim.1      Dim.2       Dim.3      Dim.4      Dim.5
# Competition 0.4011568 0.00739783 0.001062332 0.03658159 0.02357972

# %%
fviz_pca_ind(res.pca, habillage = 13,
            addEllipses = TRUE,
            ellipse.type = "confidence",
            palette = "jco", 
            repel = TRUE)
# Out:
# plot without title

# %% [markdown]
# ### Filtering results

# %%
# Visualize variable with cos2 >= 0.6
fviz_pca_var(res.pca, select.var = list(cos2 = 0.6))
# Out:
# plot without title

# %%
# Top 5 active variables with the highest cos2
fviz_pca_var(res.pca, select.var = list(cos2 = 5))
# Out:
# plot without title

# %%
# Select by names
name <- list(name = c("Long.jump", "High.jump", "X100m"))
fviz_pca_var(res.pca, select.var = name)
# Out:
# plot without title

# %%
# top 5 contributing individuals and variable
fviz_pca_biplot(res.pca, select.ind = list(contrib = 5),
               select.var = list(contrib = 5),
               ggthem = theme_minimal())
# Out:
# plot without title

# %% [markdown]
# ### Exporting result

# %% [markdown]
# #### Export plots to PDF/PNG files

# %%
# Scree plot
scree.plot <- fviz_eig(res.pca)
# Plot of individuals
ind.plot <- fviz_pca_ind(res.pca)
# Plot of variables
var.plot <- fviz_pca_var(res.pca)

# %%
pdf("../data/PCA.pdf")  # Create a new pdf device
print(scree.plot)
print(ind.plot)
print(var.plot)
dev.off()  # Close the pdf device
# Out:
# png
#   2

# %%
# Print scree plot to a png file
png("../data/pca-scree-plot.png")
print(scree.plot)
dev.off()
# Out:
# png
#   2

# %%
# Print individuals plot to a png file
png("../data/pca-variables.png")
print(var.plot)
dev.off()
# Out:
# png
#   2

# %%
# Print variables plot to a png file
png("../data/pca-individuals.png")
print(ind.plot)
dev.off()
# Out:
# png
#   2

# %%
library(ggpubr)
ggexport(plotlist = list(scree.plot, ind.plot, var.plot),
filename = "../data/PCA.pdf")
# Out:
# Loading required package: magrittr
# file saved to ../data/PCA.pdf

# %%
ggexport(plotlist = list(scree.plot, ind.plot, var.plot),
         nrow = 2, ncol = 2,
         filename = "../data/PCA.pdf")
# Out:
# file saved to ../data/PCA.pdf

# %%
ggexport(plotlist = list(scree.plot, ind.plot, var.plot),
         filename = "../data/PCA.png")
# Out:
# [1] "../data/PCA%03d.png"
# file saved to ../data/PCA%03d.png

# %% [markdown]
# #### Export results txt/csv files

# %%
# Export into a TXT file
write.infile(res.pca, "../data/pca.txt", sep = "\t")

# %%
# Export into a CSV file
write.infile(res.pca, "../data/pca.csv", sep = ";")
